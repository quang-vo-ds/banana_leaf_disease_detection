# %% [markdown]
# <a href="https://colab.research.google.com/github/quang-vo-ds/banana_leaf_disease_detection/blob/main/banana_leaf_disease_read_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Initial Setup

# %%
import os
import glob
import pickle
import numpy as np
import pandas as pd
import csv

from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Vin_ML_Course/Final_Project
root_dir = os.getcwd()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Vin_ML_Course/Final_Project

# %% [markdown]
# ## Create CSV Data

# %%
class_int_to_name = {
    0: "healthy",
    1: "aphids",
    2: "bacterial_wilt",
    3: "black_segatoka",
    4: "xanthomonas_wilt"
}
class_name_to_int = {v:k for k,v in class_int_to_name.items()}
print("Map class name to integer: ", class_name_to_int)
# Out:
# Map class name to integer:  {'healthy': 0, 'aphids': 1, 'bacterial_wilt': 2, 'black_segatoka': 3, 'xanthomonas_wilt': 4}

# %%
csv_data = {'id': [], 'label': [], 'label_name':[], 'path': []}
for k, v in class_int_to_name.items():
    class_path = os.path.join(root_dir, "data", "Banana___"+v)
    for f in glob.glob(class_path + '/*'):
        f_name = f[f.rfind("/")+1:]

        # id and class
        csv_data['id'].append(f_name)
        csv_data['label'].append(k)
        csv_data['label_name'].append(v)
        csv_data['path'].append(f)

csv_data = pd.DataFrame(csv_data)
csv_data = csv_data.dropna()
csv_data
# Out:
#                             id  label        label_name  \
# 0      Banana___Healthy_29.jpg      0           healthy
# 1     Banana___Healthy_295.jpg      0           healthy
# 2     Banana___Healthy_189.jpg      0           healthy
# 3     Banana___Healthy_141.jpg      0           healthy
# 4     Banana___Healthy_226.jpg      0           healthy
# ...                        ...    ...               ...
# 2755       20210220_110039.jpg      4  xanthomonas_wilt
# 2756       20210220_110022.jpg      4  xanthomonas_wilt
# 2757       20210220_110054.jpg      4  xanthomonas_wilt
# 2758       20210220_110019.jpg      4  xanthomonas_wilt
# 2759       20210220_110016.jpg      4  xanthomonas_wilt
#
#                                                    path
# 0     /content/drive/MyDrive/Vin_ML_Course/Final_Pro...
# 1     /content/drive/MyDrive/Vin_ML_Course/Final_Pro...
# 2     /content/drive/MyDrive/Vin_ML_Course/Final_Pro...
# 3     /content/drive/MyDrive/Vin_ML_Course/Final_Pro...
# 4     /content/drive/MyDrive/Vin_ML_Course/Final_Pro...
# ...                                                 ...
# 2755  /content/drive/MyDrive/Vin_ML_Course/Final_Pro...
# 2756  /content/drive/MyDrive/Vin_ML_Course/Final_Pro...
# 2757  /content/drive/MyDrive/Vin_ML_Course/Final_Pro...
# 2758  /content/drive/MyDrive/Vin_ML_Course/Final_Pro...
# 2759  /content/drive/MyDrive/Vin_ML_Course/Final_Pro...
#
# [2760 rows x 4 columns]

# %% [markdown]
# ## Save file

# %%
# Create processsed_data directory
save_dir = os.path.join(root_dir, "output/processed_data")
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# Save csv_data,
csv_data.to_csv(os.path.join(save_dir, "csv_data.csv"), index=False)
